# %% [markdown]
# ## **DAX Functions in Power BI**
#
# ### **Assignment Questions**
#
# You are working as a **Data Analyst for a retail company**. The management wants interactive Power BI reports
# using **DAX (Data Analysis Expressions)** to analyze sales, profit, rankings, and time-based performance.
#
# Your task is to **create calculated columns, measures, calculated tables, and KPIs using DAX**.
#
# **Dataset:** [**Amazon Store Sales Dataset** ](https://drive.google.com/file/d/1zv9tMsT2cqTtsAEozIJknYmzAx2JpodC/view)
#
# **Rows: 500**
#
# **Columns: 10**
#
# **Column Description**
#
# **1. OrderID** – Unique order identifier
#
# **2. OrderDate** – Date of purchase
#
# **3. ProductID** – Unique product identifier
#
# **4. ProductCategory** – Product category
#
# **5. Quantity** – Units sold
#
# **6. UnitPrice** – Price per unit
#
# **7. Discount** – Discount percentage (0–30%)
#
# **8. SalesAmount** – Total billed amount
#
# **9. Region** – Sales region
#
# **10. SalesChannel** – Online / Mobile App

# %% [markdown]
# **Tasks to be performed :**
#
# **Q1.** Create a calculated column **TotalPrice** using **Quantity** and **Unit Price**.
#
# **Ans-**
#
# ![P2Q1.png](data:image/png;base64,...)

# %% [markdown]
# **Q2.** Create a calculated column Discounted Price.
#
# **Ans-**
#
# ![P2Q2.png](data:image/png;base64,...)

# %% [markdown]
# **Q3.** Create a measure Average Order Value (AOV).
#
# **Ans-**
#
# ![P2Q3.png](data:image/png;base64,...)

# %% [markdown]
# **Q4.** Using DAX, create a measure that calculates cumulative Year-to-Date (YTD) Sales based on the Order Date.
#
# **Ans-**
#
# ![P2Q4(1).png](data:image/png;base64,...)
#
# ![P2Q4(2).png](data:image/png;base64,...)

# %% [markdown]
# **Q5.** Using DAX, create a measure to rank each product according to its Total Sales, with the highest-selling product ranked first.
#
# **Ans-**
#
# ![P2Q5.png](data:image/png;base64,...)

# %% [markdown]
# **Q6.** Create a calculated column classifying orders as **“High Value”** if sales > 2000, else **“Low Value”**.
#
# **Ans-**
#
# ![P2Q6.png](data:image/png;base64,...)

# %% [markdown]
# **Q7.** Create a measure to calculate **total sales from the Online channel only**.
#
# **Ans-**
#
# ![P2Q7.png](data:image/png;base64,...)

# %% [markdown]
# **Q8.** Create a measure called "Date Difference" that calculates the number of days between the latest  Order Date and today's date using the DATEDIFF function.
#
# **Ans-**
#
# ![P2Q8.png](data:image/png;base64,...)
